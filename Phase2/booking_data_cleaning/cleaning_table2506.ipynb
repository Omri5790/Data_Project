# %%
import pandas as pd
import numpy as np

# Load the CSV file
df = pd.read_csv('./2506_booking hotels.csv')

# Display the initial columns and data types
print("Initial DataFrame columns and data types:")
print(df.dtypes)

# Drop the 'location' column if it exists
if 'location' in df.columns:
    df = df.drop(columns=['location'])

# Step 1: Create a new column 'neighborhood' from the string up to the first comma
df['neighborhood'] = df['bed_type'].apply(lambda x: x.split(',')[0] if pd.notnull(x) else np.nan)

# Remove the neighborhood part from the 'bed_type' column
df['bed_type'] = df['bed_type'].apply(lambda x: ','.join(x.split(',')[1:]) if pd.notnull(x) else np.nan)

# Step 2: Extract the distance value
df['km_from_center'] = df['bed_type'].str.extract(r'(\d.{0,5})')

# Clean the km_from_center column by keeping only digits and the dot character
df['km_from_center'] = df['km_from_center'].str.replace(r'[^\d.]', '', regex=True)

# Convert the cleaned column to float
df['km_from_center'] = df['km_from_center'].astype(float)

# For values greater than 100, divide them by 1000
df.loc[df['km_from_center'] > 100, 'km_from_center'] /= 1000

# Clean the "reviews" column to keep only the number of reviews
df['reviews'] = df['reviews'].str.replace(r'\D', '', regex=True).astype(float)

# Clean the "score" column to keep only the score number
df['score'] = df['score'].astype(str).str.extract('(\d+\.?\d*)').astype(float)

df['location_rating'] = df['location_rating'].astype(str).str.extract('(\d+\.?\d*)').astype(float)

# Clean the "price" column to keep only the price number
df['price'] = df['price'].astype(str).str.replace(r'[^\d.]', '', regex=True).astype(float)

# Calculate the price per night
df['price_per_night'] = df['price'] / df['los']

# Clean the "star_rating" column to take the first number if it's not N/A
df['star_rating'] = df['star_rating'].apply(lambda x: float(x[0]) if isinstance(x, str) and x != 'N/A' else np.nan)

# Change "Yes" to 1 and "No" to 0 in the "Free_cancellation" column
df['Free_cancellation'] = df['Free_cancellation'].apply(lambda x: 1 if x == 'Yes' else 0)

# Clean the "Limited_rooms" column
df['Limited_rooms'] = df['Limited_rooms'].apply(lambda x: 1 if x == 'Yes' else (0 if x == 'No' else x))
df['Limited_rooms'] = pd.to_numeric(df['Limited_rooms'], errors='coerce').fillna(0).astype(int)

df['Breakfast'] = df['Breakfast'].apply(lambda x: 1 if x == 'Breakfast included' else 0)


# Display the cleaned DataFrame
print("Final cleaned DataFrame:")
print(df.head())
print("DataFrame columns and data types after cleaning:")
print(df.dtypes)

# Save the cleaned DataFrame to a new CSV file
df.to_csv('./2506_cleaned_booking_hotels.csv', index=False)
# Out:
# Initial DataFrame columns and data types:
# name                  object
# location             float64
# score                 object
# reviews               object
# room_type             object
# bed_type              object
# price                 object
# availability          object
# los                    int64
# url                   object
# star_rating           object
# location_rating       object
# Snapshot              object
# Free_cancellation     object
# No_prepayment         object
# Limited_rooms         object
# TTT                    int64
# Breakfast             object
# index                  int64
# dtype: object
# Final cleaned DataFrame:
#                         name  score  reviews  \
# 0         Bowery Grand Hotel    3.5   1414.0
# 1         U.S. Pacific Hotel    5.6   2450.0
# 2             West Side YMCA    6.6  13601.0
# 3             Hotel Moca NYC    4.3     98.0
# 4  The Nolita Express Hostel    7.1    139.0
#
#                                    room_type  \
# 0  Standard Double Room with Shared Bathroom
# 1                Standard Double (No Window)
# 2         Bunk Bed Room with Shared Bathroom
# 3                          Deluxe Queen Room
# 4             Small Vintage Pod - All Gender
#
#                                             bed_type  price  \
# 0   New YorkShow on map5.6 km from centreMetro ac...  106.0
# 1   New YorkShow on map5.7 km from centreMetro ac...  129.0
# 2   New YorkShow on map350 m from centreMetro access  130.0
# 3   New YorkShow on map9.9 km from centreMetro ac...  157.0
# 4   New YorkShow on map5.2 km from centreMetro ac...  188.0
#
#         availability  los                                                url  \
# 0  1 night, 2 adults    1  https://www.booking.com/hotel/us/bowery-grand....
# 1  1 night, 2 adults    1  https://www.booking.com/hotel/us/us-pacific.en...
# 2  1 night, 2 adults    1  https://www.booking.com/hotel/us/west-side-ymc...
# 3  1 night, 2 adults    1  https://www.booking.com/hotel/us/moca-nyc.en-g...
# 4  1 night, 2 adults    1  https://www.booking.com/hotel/us/the-nolita-ex...
#
#    star_rating  ...    Snapshot Free_cancellation  No_prepayment  \
# 0          1.0  ...  2024-06-25                 0             No
# 1          1.0  ...  2024-06-25                 0             No
# 2          3.0  ...  2024-06-25                 0             No
# 3          3.0  ...  2024-06-25                 0             No
# 4          NaN  ...  2024-06-25                 0             No
#
#   Limited_rooms  TTT  Breakfast  index        neighborhood km_from_center  \
# 0             0    1          0      1     Lower East Side           5.60
# 1             0    1          0      2           Chinatown           5.70
# 2             0    1          0      3     Upper West Side           0.35
# 3             0    1          0      4  Washington Heights           9.90
# 4             0    1          0      5                SoHo           5.20
#
#    price_per_night
# 0            106.0
# 1            129.0
# 2            130.0
# 3            157.0
# 4            188.0
#
# [5 rows x 21 columns]
# DataFrame columns and data types after cleaning:
# name                  object
# score                float64
# reviews              float64
# room_type             object
# bed_type              object
# price                float64
# availability          object
# los                    int64
# url                   object
# star_rating          float64
# location_rating      float64
# Snapshot              object
# Free_cancellation      int64
# No_prepayment         object
# Limited_rooms          int32
# TTT                    int64
# Breakfast              int64
# index                  int64
# neighborhood          object
# km_from_center       float64
# price_per_night      float64
# dtype: object

# %%
import pandas as pd

# Load the CSV file
df = pd.read_csv('./2506_cleaned_booking_hotels.csv')

# Ensure the price column is treated as a float
# Assuming 'price_per_night' is already numerical
df['price_per_night'] = df['price_per_night'].astype(float)

# Calculate Q1 (25th percentile) and Q3 (75th percentile)
Q1 = df['price_per_night'].quantile(0.25)
Q3 = df['price_per_night'].quantile(0.75)

# Calculate the IQR (Interquartile Range)
IQR = Q3 - Q1

# Determine the lower and upper bounds for outliers
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Remove outliers
df_no_outliers = df[(df['price_per_night'] >= lower_bound) & (df['price_per_night'] <= upper_bound)]

print(f"Original DataFrame shape: {df.shape}")
print(f"DataFrame shape after removing outliers: {df_no_outliers.shape}")

df_no_outliers.to_csv('./2506_cleaned_booking_hotels.csv', index=False)

df_no_outliers.T
# Out:
# Original DataFrame shape: (26320, 21)
# DataFrame shape after removing outliers: (25849, 21)
#                                                                1      \
# name                                              U.S. Pacific Hotel
# score                                                            5.6
# reviews                                                       2450.0
# room_type                                Standard Double (No Window)
# bed_type            New YorkShow on map5.7 km from centreMetro ac...
# price                                                          129.0
# availability                                       1 night, 2 adults
# los                                                                1
# url                https://www.booking.com/hotel/us/us-pacific.en...
# star_rating                                                      1.0
# location_rating                                                  NaN
# Snapshot                                                  2024-06-25
# Free_cancellation                                                  0
# No_prepayment                                                     No
# Limited_rooms                                                      0
# TTT                                                                1
# Breakfast                                                          0
# index                                                              2
# neighborhood                                               Chinatown
# km_from_center                                                   5.7
# price_per_night                                                129.0
#
#                                                                2      \
# name                                                  West Side YMCA
# score                                                            6.6
# reviews                                                      13601.0
# room_type                         Bunk Bed Room with Shared Bathroom
# bed_type            New YorkShow on map350 m from centreMetro access
# price                                                          130.0
# availability                                       1 night, 2 adults
# los                                                                1
# url                https://www.booking.com/hotel/us/west-side-ymc...
# star_rating                                                      3.0
# location_rating                                                  9.4
# Snapshot                                                  2024-06-25
# Free_cancellation                                                  0
# No_prepayment                                                     No
# Limited_rooms                                                      0
# TTT                                                                1
# Breakfast                                                          0
# index                                                              3
# neighborhood                                         Upper West Side
# km_from_center                                                  0.35
# price_per_night                                                130.0
#
#                                                                3      \
# name                                                  Hotel Moca NYC
# score                                                            4.3
# reviews                                                         98.0
# room_type                                          Deluxe Queen Room
# bed_type            New YorkShow on map9.9 km from centreMetro ac...
# price                                                          157.0
# availability                                       1 night, 2 adults
# los                                                                1
# url                https://www.booking.com/hotel/us/moca-nyc.en-g...
# star_rating                                                      3.0
# location_rating                                                  NaN
# Snapshot                                                  2024-06-25
# Free_cancellation                                                  0
# No_prepayment                                                     No
# Limited_rooms                                                      0
# TTT                                                                1
# Breakfast                                                          0
# index                                                              4
# neighborhood                                      Washington Heights
# km_from_center                                                   9.9
# price_per_night                                                157.0
#
#                                                                4      \
# name                                       The Nolita Express Hostel
# score                                                            7.1
# reviews                                                        139.0
# room_type                             Small Vintage Pod - All Gender
# bed_type            New YorkShow on map5.2 km from centreMetro ac...
# price                                                          188.0
# availability                                       1 night, 2 adults
# los                                                                1
# url                https://www.booking.com/hotel/us/the-nolita-ex...
# star_rating                                                      NaN
# location_rating                                                  NaN
# Snapshot                                                  2024-06-25
# Free_cancellation                                                  0
# No_prepayment                                                     No
# Limited_rooms                                                      0
# TTT                                                                1
# Breakfast                                                          0
# index                                                              5
# neighborhood                                                    SoHo
# km_from_center                                                   5.2
# price_per_night                                                188.0
#
#                                                                5      \
# name                                               KAMA CENTRAL PARK
# score                                                            7.6
# reviews                                                       2062.0
# room_type                        Single Bed in Female Dormitory Room
# bed_type            New YorkShow on map3.8 km from centreMetro ac...
# price                                                          197.0
# availability                                       1 night, 2 adults
# los                                                                1
# url                https://www.booking.com/hotel/us/kama-central-...
# star_rating                                                      1.0
# location_rating                                                  NaN
# Snapshot                                                  2024-06-25
# Free_cancellation                                                  0
# No_prepayment                                                     No
# Limited_rooms                                                      0
# TTT                                                                1
# Breakfast                                                          0
# index                                                              6
# neighborhood                                         Upper West Side
# km_from_center                                                   3.8
# price_per_night                                                197.0
#
#                                                                6      \
# name                                              Hudson River Hotel
# score                                                            5.5
# reviews                                                       2360.0
# room_type                                    King Room - Non-Smoking
# bed_type            New YorkShow on map1.9 km from centreMetro ac...
# price                                                          199.0
# availability                                       1 night, 2 adults
# los                                                                1
# url                https://www.booking.com/hotel/us/inn-midtown-w...
# star_rating                                                      3.0
# location_rating                                                  NaN
# Snapshot                                                  2024-06-25
# Free_cancellation                                                  0
# No_prepayment                                                     No
# Limited_rooms                                                      0
# TTT                                                                1
# Breakfast                                                          0
# index                                                              7
# neighborhood                                            Hudson Yards
# km_from_center                                                   1.9
# price_per_night                                                199.0
#
#                                                                7      \
# name                                                     Radio Hotel
# score                                                            8.0
# reviews                                                       1307.0
# room_type                                            Standard Studio
# bed_type            New YorkShow on map9.8 km from centreMetro ac...
# price                                                          204.0
# availability                                       1 night, 2 adults
# los                                                                1
# url                https://www.booking.com/hotel/us/radio.en-gb.h...
# star_rating                                                      4.0
# location_rating                                                  NaN
# Snapshot                                                  2024-06-25
# Free_cancellation                                                  0
# No_prepayment                                                     No
# Limited_rooms                                                      0
# TTT                                                                1
# Breakfast                                                          0
# index                                                              8
# neighborhood                                      Washington Heights
# km_from_center                                                   9.8
# price_per_night                                                204.0
#
#                                                                8      \
# name                                                 Hudson Yard 408
# score                                                            4.9
# reviews                                                         44.0
# room_type                                                Double Room
# bed_type            New YorkShow on map1.9 km from centreMetro ac...
# price                                                          210.0
# availability                                       1 night, 2 adults
# los                                                                1
# url                https://www.booking.com/hotel/us/hudson-new-yo...
# star_rating                                                      NaN
# location_rating                                                  NaN
# Snapshot                                                  2024-06-25
# Free_cancellation                                                  0
# No_prepayment                                                     No
# Limited_rooms                                                      0
# TTT                                                                1
# Breakfast                                                          0
# index                                                              9
# neighborhood                                            Hudson Yards
# km_from_center                                                   1.9
# price_per_night                                                210.0
#
#                                                                9      \
# name                             Nap York Central Park Sleep Station
# score                                                            8.2
# reviews                                                       4369.0
# room_type                            Economy Pod in 6 Bed Mixed Dorm
# bed_type            New YorkShow on map300 m from centreMetro access
# price                                                          211.0
# availability                                       1 night, 2 adults
# los                                                                1
# url                https://www.booking.com/hotel/us/nap-york-new-...
# star_rating                                                      1.0
# location_rating                                                  9.5
# Snapshot                                                  2024-06-25
# Free_cancellation                                                  0
# No_prepayment                                                     No
# Limited_rooms                                                      0
# TTT                                                                1
# Breakfast                                                          0
# index                                                             10
# neighborhood                                               Manhattan
# km_from_center                                                   0.3
# price_per_night                                                211.0
#
#                                                                10     ...  \
# name                                               Lamartine Chelsea  ...
# score                                                            6.5  ...
# reviews                                                        437.0  ...
# room_type                           Double Room with Shared Bathroom  ...
# bed_type            New YorkShow on map2.4 km from centreMetro ac...  ...
# price                                                          243.0  ...
# availability                                       1 night, 2 adults  ...
# los                                                                1  ...
# url                https://www.booking.com/hotel/us/incentra-home...  ...
# star_rating                                                      1.0  ...
# location_rating                                                  NaN  ...
# Snapshot                                                  2024-06-25  ...
# Free_cancellation                                                  0  ...
# No_prepayment                                                     No  ...
# Limited_rooms                                                      0  ...
# TTT                                                                1  ...
# Breakfast                                                          0  ...
# index                                                             11  ...
# neighborhood                                                 Chelsea  ...
# km_from_center                                                   2.4  ...
# price_per_night                                                243.0  ...
#
#                                                                26310  \
# name                           Gild Hall, A Thompson Hotel, by Hyatt
# score                                                            8.6
# reviews                                                        354.0
# room_type                                                  King Room
# bed_type             New YorkShow on map7 km from centreMetro access
# price                                                         1420.0
# availability                                      5 nights, 2 adults
# los                                                                5
# url                https://www.booking.com/hotel/us/gild-hall-tho...
# star_rating                                                      4.0
# location_rating                                                  NaN
# Snapshot                                                  2024-06-25
# Free_cancellation                                                  0
# No_prepayment                                                     No
# Limited_rooms                                                      0
# TTT                                                               30
# Breakfast                                                          0
# index                                                            166
# neighborhood                                               Manhattan
# km_from_center                                                   7.0
# price_per_night                                                284.0
#
#                                                                26311  \
# name                                           45 Times Square Hotel
# score                                                            8.3
# reviews                                                       1762.0
# room_type                                        Standard Queen Room
# bed_type            New YorkShow on map1.2 km from centreMetro ac...
# price                                                         1420.0
# availability                                      5 nights, 2 adults
# los                                                                5
# url                https://www.booking.com/hotel/us/45-times-squa...
# star_rating                                                      3.0
# location_rating                                                  9.6
# Snapshot                                                  2024-06-25
# Free_cancellation                                                  1
# No_prepayment                                                     No
# Limited_rooms                                                      0
# TTT                                                               30
# Breakfast                                                          0
# index                                                            167
# neighborhood                                               Manhattan
# km_from_center                                                   1.2
# price_per_night                                                284.0
#
#                                                                26312  \
# name                                                      JG Sohotel
# score                                                            7.3
# reviews                                                        201.0
# room_type                                                 Queen Room
# bed_type            New YorkShow on map5.7 km from centreMetro ac...
# price                                                         1421.0
# availability                                      5 nights, 2 adults
# los                                                                5
# url                https://www.booking.com/hotel/us/jg-sohotel.en...
# star_rating                                                      3.0
# location_rating                                                  NaN
# Snapshot                                                  2024-06-25
# Free_cancellation                                                  1
# No_prepayment                                                     No
# Limited_rooms                                                      0
# TTT                                                               30
# Breakfast                                                          0
# index                                                            168
# neighborhood                                                    SoHo
# km_from_center                                                   5.7
# price_per_night                                                284.2
#
#                                                                26313  \
# name                                    Heritage Hotel New York City
# score                                                            7.2
# reviews                                                       3477.0
# room_type                                    King Room - Non-Smoking
# bed_type            New YorkShow on map2.8 km from centreMetro ac...
# price                                                         1421.0
# availability                                      5 nights, 2 adults
# los                                                                5
# url                https://www.booking.com/hotel/us/heritage-new-...
# star_rating                                                      3.0
# location_rating                                                  NaN
# Snapshot                                                  2024-06-25
# Free_cancellation                                                  0
# No_prepayment                                                     No
# Limited_rooms                                                      0
# TTT                                                               30
# Breakfast                                                          0
# index                                                            169
# neighborhood                                       Flatiron District
# km_from_center                                                   2.8
# price_per_night                                                284.2
#
#                                                                26314  \
# name               Distrikt Hotel New York City, Tapestry Collect...
# score                                                            7.5
# reviews                                                        346.0
# room_type                                                 Queen Room
# bed_type            New YorkShow on map1.6 km from centreMetro ac...
# price                                                         1423.0
# availability                                      5 nights, 2 adults
# los                                                                5
# url                https://www.booking.com/hotel/us/distrikt-new-...
# star_rating                                                      4.0
# location_rating                                                  NaN
# Snapshot                                                  2024-06-25
# Free_cancellation                                                  0
# No_prepayment                                                     No
# Limited_rooms                                                      0
# TTT                                                               30
# Breakfast                                                          0
# index                                                            170
# neighborhood                                          Hell's Kitchen
# km_from_center                                                   1.6
# price_per_night                                                284.6
#
#                                                                26315  \
# name                                       Fitzpatrick Grand Central
# score                                                            8.2
# reviews                                                        632.0
# room_type                                                Deluxe Room
# bed_type            New YorkShow on map1.8 km from centreMetro ac...
# price                                                         1423.0
# availability                                      5 nights, 2 adults
# los                                                                5
# url                https://www.booking.com/hotel/us/fitzpatrick-g...
# star_rating                                                      4.0
# location_rating                                                  9.5
# Snapshot                                                  2024-06-25
# Free_cancellation                                                  1
# No_prepayment                                                    Yes
# Limited_rooms                                                      0
# TTT                                                               30
# Breakfast                                                          0
# index                                                            171
# neighborhood                                            Midtown East
# km_from_center                                                   1.8
# price_per_night                                                284.6
#
#                                                                26316  \
# name                          AC Hotel by Marriott New York Downtown
# score                                                            8.5
# reviews                                                       1721.0
# room_type               King Guest Room - One King Bed - Non-Smoking
# bed_type            New YorkShow on map7.2 km from centreMetro ac...
# price                                                         1427.0
# availability                                      5 nights, 2 adults
# los                                                                5
# url                https://www.booking.com/hotel/us/ac-new-york-d...
# star_rating                                                      4.0
# location_rating                                                  NaN
# Snapshot                                                  2024-06-25
# Free_cancellation                                                  0
# No_prepayment                                                     No
# Limited_rooms                                                      0
# TTT                                                               30
# Breakfast                                                          0
# index                                                            172
# neighborhood                                               Manhattan
# km_from_center                                                   7.2
# price_per_night                                                285.4
#
#                                                                26317  \
# name                                                   Moderne Hotel
# score                                                            7.9
# reviews                                                        952.0
# room_type                                                Deluxe Room
# bed_type            New YorkShow on map350 m from centreMetro access
# price                                                         1427.0
# availability                                      5 nights, 2 adults
# los                                                                5
# url                https://www.booking.com/hotel/us/monderne.en-g...
# star_rating                                                      4.0
# location_rating                                                  9.4
# Snapshot                                                  2024-06-25
# Free_cancellation                                                  0
# No_prepayment                                                     No
# Limited_rooms                                                      0
# TTT                                                               30
# Breakfast                                                          0
# index                                                            173
# neighborhood                                               Manhattan
# km_from_center                                                  0.35
# price_per_night                                                285.4
#
#                                                                26318  \
# name                                Hampton Inn Times Square Central
# score                                                            8.3
# reviews                                                       2987.0
# room_type                                    King Room - Non-Smoking
# bed_type            New YorkShow on map1.5 km from centreMetro ac...
# price                                                         1428.0
# availability                                      5 nights, 2 adults
# los                                                                5
# url                https://www.booking.com/hotel/us/hampton-inn-t...
# star_rating                                                      3.0
# location_rating                                                  9.5
# Snapshot                                                  2024-06-25
# Free_cancellation                                                  0
# No_prepayment                                                     No
# Limited_rooms                                                      0
# TTT                                                               30
# Breakfast                                                          1
# index                                                            174
# neighborhood                                               Manhattan
# km_from_center                                                   1.5
# price_per_night                                                285.6
#
#                                                                26319
# name                              Renaissance New York Chelsea Hotel
# score                                                            8.0
# reviews                                                        913.0
# room_type                                         Guest Room, 1 King
# bed_type            New YorkShow on map2.8 km from centreMetro ac...
# price                                                         1432.0
# availability                                      5 nights, 2 adults
# los                                                                5
# url                https://www.booking.com/hotel/us/renaissance-n...
# star_rating                                                      4.0
# location_rating                                                  NaN
# Snapshot                                                  2024-06-25
# Free_cancellation                                                  1
# No_prepayment                                                    Yes
# Limited_rooms                                                      0
# TTT                                                               30
# Breakfast                                                          0
# index                                                            175
# neighborhood                                                 Chelsea
# km_from_center                                                   2.8
# price_per_night                                                286.4
#
# [21 rows x 25849 columns]
