# %% [markdown]
# ## The attached code is a run of the linear regression model on data from booking without the addition of new features

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split, cross_validate
from sklearn.linear_model import LinearRegression
from sklearn.impute import SimpleImputer
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error, make_scorer
import matplotlib.pyplot as plt
import seaborn as sns

# Load the data
df1 = pd.read_csv('./0507_cleaned_booking_hotels.csv')
df2 = pd.read_csv('./2506_cleaned_booking_hotels.csv')
df3 = pd.read_csv('./20_06_hotels_data_cleaned.csv')

# Merge the dataframes
df = pd.concat([df1, df2, df3], ignore_index=True)

# Function to fill NaN values with the mean of the group
def fill_na_with_group_mean(df):
    numeric_cols = df.select_dtypes(include=[np.number]).columns
    for col in numeric_cols:
        df[col].fillna(df[col].mean(), inplace=True)
    return df

# Fill NaN values for the entire dataset
df = fill_na_with_group_mean(df)

# Keep only numeric columns
df = df.select_dtypes(include=[np.number])

# Remove columns with all NaN values
df = df.dropna(axis=1, how='all')

# Remove the price column
if 'price_per_night' in df.columns:
    df = df.drop(columns=['price_per_night'])

# Ensure there are no remaining NaN values
imputer = SimpleImputer(strategy='mean')
df = pd.DataFrame(imputer.fit_transform(df), columns=df.columns)

# Split the data into train and test sets
X = df.drop(columns=['price'])
y = df['price']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Initialize and fit the Linear Regression model
model = LinearRegression()
model.fit(X_train, y_train)

# Predictions
y_train_pred = model.predict(X_train)
y_test_pred = model.predict(X_test)

# Training metrics
train_r2 = r2_score(y_train, y_train_pred)
train_rmse = mean_squared_error(y_train, y_train_pred, squared=False)
train_mse = mean_squared_error(y_train, y_train_pred)
train_mae = mean_absolute_error(y_train, y_train_pred)

# Test metrics
test_r2 = r2_score(y_test, y_test_pred)
test_rmse = mean_squared_error(y_test, y_test_pred, squared=False)
test_mse = mean_squared_error(y_test, y_test_pred)
test_mae = mean_absolute_error(y_test, y_test_pred)

# Print results
print("Linear Regression Results:")
print(f"Train R2: {train_r2}")
print(f"Train RMSE: {train_rmse}")
print(f"Train MSE: {train_mse}")
print(f"Train MAE: {train_mae}")
print(f"Test R2: {test_r2}")
print(f"Test RMSE: {test_rmse}")
print(f"Test MSE: {test_mse}")
print(f"Test MAE: {test_mae}")

# Cross-validation
scoring = {
    'r2': make_scorer(r2_score),
    'mae': make_scorer(mean_absolute_error),
    'rmse': make_scorer(mean_squared_error, squared=False),
    'mse': make_scorer(mean_squared_error)
}
cv_results = cross_validate(model, X, y, cv=5, scoring=scoring, return_train_score=True)

# Average cross-validation metrics
cv_r2 = np.mean(cv_results['test_r2'])
cv_rmse = np.mean(cv_results['test_rmse'])
cv_mse = np.mean(cv_results['test_mse'])
cv_mae = np.mean(cv_results['test_mae'])

print("Cross-Validation Results (Average):")
print(f"CV R2: {cv_r2}")
print(f"CV RMSE: {cv_rmse}")
print(f"CV MSE: {cv_mse}")
print(f"CV MAE: {cv_mae}")

# Plot actual vs predicted prices
plt.figure(figsize=(10, 6))
sns.scatterplot(x=y_test, y=y_test_pred, alpha=0.6)
plt.xlabel('Actual Prices')
plt.ylabel('Predicted Prices')
plt.title('Actual vs Predicted Prices - Linear Regression')
plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], color='red', linestyle='--')
plt.show()

# Residual plot
residuals = y_test - y_test_pred
plt.figure(figsize=(10, 6))
sns.scatterplot(x=y_test, y=residuals, alpha=0.6)
plt.axhline(y=0, color='red', linestyle='--')
plt.xlabel('Actual Prices')
plt.ylabel('Residuals')
plt.title('Residuals Plot - Linear Regression')
plt.show()

# Graph comparing train, test, and cross-validation results for R2, RMSE, MAE
metrics = ['R2', 'RMSE', 'MAE']
train_metrics = [train_r2, train_rmse, train_mae]
test_metrics = [test_r2, test_rmse, test_mae]
cv_metrics = [cv_r2, cv_rmse, cv_mae]

x = np.arange(len(metrics))
width = 0.2

fig, ax = plt.subplots(1, 3, figsize=(18, 6))

# R2 Score
ax[0].bar(x - width, train_metrics[:1], width, label='Train')
ax[0].bar(x, test_metrics[:1], width, label='Test')
ax[0].bar(x + width, cv_metrics[:1], width, label='CV')
ax[0].set_xlabel('R2 Score')
ax[0].set_ylabel('Values')
ax[0].set_title('Comparison of Train, Test, and Cross-Validation Metrics for R2')
ax[0].set_xticks([0])
ax[0].set_xticklabels(['R2'])
ax[0].legend()

# RMSE
ax[1].bar(x - width, train_metrics[1:2], width, label='Train')
ax[1].bar(x, test_metrics[1:2], width, label='Test')
ax[1].bar(x + width, cv_metrics[1:2], width, label='CV')
ax[1].set_xlabel('RMSE')
ax[1].set_ylabel('Values')
ax[1].set_title('Comparison of Train, Test, and Cross-Validation Metrics for RMSE')
ax[1].set_xticks([1])
ax[1].set_xticklabels(['RMSE'])
ax[1].legend()

# MAE
ax[2].bar(x - width, train_metrics[2:], width, label='Train')
ax[2].bar(x, test_metrics[2:], width, label='Test')
ax[2].bar(x + width, cv_metrics[2:], width, label='CV')
ax[2].set_xlabel('MAE')
ax[2].set_ylabel('Values')
ax[2].set_title('Comparison of Train, Test, and Cross-Validation Metrics for MAE')
ax[2].set_xticks([2])
ax[2].set_xticklabels(['MAE'])
ax[2].legend()

plt.show()
# Out:
# Linear Regression Results:
# Train R2: 0.8981198714863523
# Train RMSE: 128.24346389281732
# Train MSE: 16446.38603122834
# Train MAE: 91.12290140676029
# Test R2: 0.8951549420175113
# Test RMSE: 129.32876587618048
# Test MSE: 16725.929683055907
# Test MAE: 91.72049364017013
# Cross-Validation Results (Average):
# CV R2: 0.8904524028097167
# CV RMSE: 130.39416667878518
# CV MSE: 17810.992505923816
# CV MAE: 94.18438264519675

# %% [markdown]
# ## The attached code is a run of the linear regression model on booking data with additions of new features and after we have done one hot encoding for them (a period of the month - beginning, middle and end, day of the week of check in, day of the week of check out)

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split, cross_validate
from sklearn.linear_model import LinearRegression
from sklearn.impute import SimpleImputer
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error, make_scorer
import matplotlib.pyplot as plt
import seaborn as sns

# Load the data
df1 = pd.read_csv('./05_07_hotels_data_cleaned_with_days_name_parameters_period_encoded.csv')
df2 = pd.read_csv('./25_06_hotels_data_cleaned_with_days_name_parameters_period_encoded.csv')
df3 = pd.read_csv('./20_06_hotels_data_cleaned_with_new_parameters_encoded.csv')

# Merge the dataframes
df = pd.concat([df1, df2, df3], ignore_index=True)

# Function to fill NaN values with the mean of the group
def fill_na_with_group_mean(df):
    numeric_cols = df.select_dtypes(include=[np.number]).columns
    for col in numeric_cols:
        df[col].fillna(df[col].mean(), inplace=True)
    return df

# Fill NaN values for the entire dataset
df = fill_na_with_group_mean(df)

# Keep only numeric columns
df = df.select_dtypes(include=[np.number])

# Remove columns with all NaN values
df = df.dropna(axis=1, how='all')

# Remove the price column
if 'price_per_night' in df.columns:
    df = df.drop(columns=['price_per_night'])

# Ensure there are no remaining NaN values
imputer = SimpleImputer(strategy='mean')
df = pd.DataFrame(imputer.fit_transform(df), columns=df.columns)

# Split the data into train and test sets
X = df.drop(columns=['price'])
y = df['price']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Initialize and fit the Linear Regression model
model = LinearRegression()
model.fit(X_train, y_train)

# Predictions
y_train_pred = model.predict(X_train)
y_test_pred = model.predict(X_test)

# Training metrics
train_r2 = r2_score(y_train, y_train_pred)
train_rmse = mean_squared_error(y_train, y_train_pred, squared=False)
train_mse = mean_squared_error(y_train, y_train_pred)
train_mae = mean_absolute_error(y_train, y_train_pred)

# Test metrics
test_r2 = r2_score(y_test, y_test_pred)
test_rmse = mean_squared_error(y_test, y_test_pred, squared=False)
test_mse = mean_squared_error(y_test, y_test_pred)
test_mae = mean_absolute_error(y_test, y_test_pred)

# Print results
print("Linear Regression Results:")
print(f"Train R2: {train_r2}")
print(f"Train RMSE: {train_rmse}")
print(f"Train MSE: {train_mse}")
print(f"Train MAE: {train_mae}")
print(f"Test R2: {test_r2}")
print(f"Test RMSE: {test_rmse}")
print(f"Test MSE: {test_mse}")
print(f"Test MAE: {test_mae}")

# Cross-validation
scoring = {
    'r2': make_scorer(r2_score),
    'mae': make_scorer(mean_absolute_error),
    'rmse': make_scorer(mean_squared_error, squared=False),
    'mse': make_scorer(mean_squared_error)
}
cv_results = cross_validate(model, X, y, cv=5, scoring=scoring, return_train_score=True)

# Average cross-validation metrics
cv_r2 = np.mean(cv_results['test_r2'])
cv_rmse = np.mean(cv_results['test_rmse'])
cv_mse = np.mean(cv_results['test_mse'])
cv_mae = np.mean(cv_results['test_mae'])

print("Cross-Validation Results (Average):")
print(f"CV R2: {cv_r2}")
print(f"CV RMSE: {cv_rmse}")
print(f"CV MSE: {cv_mse}")
print(f"CV MAE: {cv_mae}")

# Plot actual vs predicted prices
plt.figure(figsize=(10, 6))
sns.scatterplot(x=y_test, y=y_test_pred, alpha=0.6)
plt.xlabel('Actual Prices')
plt.ylabel('Predicted Prices')
plt.title('Actual vs Predicted Prices - Linear Regression')
plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], color='red', linestyle='--')
plt.show()

# Residual plot
residuals = y_test - y_test_pred
plt.figure(figsize=(10, 6))
sns.scatterplot(x=y_test, y=residuals, alpha=0.6)
plt.axhline(y=0, color='red', linestyle='--')
plt.xlabel('Actual Prices')
plt.ylabel('Residuals')
plt.title('Residuals Plot - Linear Regression')
plt.show()

# Graph comparing train, test, and cross-validation results for R2, RMSE, MAE
metrics = ['R2', 'RMSE', 'MAE']
train_metrics = [train_r2, train_rmse, train_mae]
test_metrics = [test_r2, test_rmse, test_mae]
cv_metrics = [cv_r2, cv_rmse, cv_mae]

x = np.arange(len(metrics))
width = 0.2

fig, ax = plt.subplots(1, 3, figsize=(18, 6))

# R2 Score
ax[0].bar(x - width, train_metrics[:1], width, label='Train')
ax[0].bar(x, test_metrics[:1], width, label='Test')
ax[0].bar(x + width, cv_metrics[:1], width, label='CV')
ax[0].set_xlabel('R2 Score')
ax[0].set_ylabel('Values')
ax[0].set_title('Comparison of Train, Test, and Cross-Validation Metrics for R2')
ax[0].set_xticks([0])
ax[0].set_xticklabels(['R2'])
ax[0].legend()

# RMSE
ax[1].bar(x - width, train_metrics[1:2], width, label='Train')
ax[1].bar(x, test_metrics[1:2], width, label='Test')
ax[1].bar(x + width, cv_metrics[1:2], width, label='CV')
ax[1].set_xlabel('RMSE')
ax[1].set_ylabel('Values')
ax[1].set_title('Comparison of Train, Test, and Cross-Validation Metrics for RMSE')
ax[1].set_xticks([1])
ax[1].set_xticklabels(['RMSE'])
ax[1].legend()

# MAE
ax[2].bar(x - width, train_metrics[2:], width, label='Train')
ax[2].bar(x, test_metrics[2:], width, label='Test')
ax[2].bar(x + width, cv_metrics[2:], width, label='CV')
ax[2].set_xlabel('MAE')
ax[2].set_ylabel('Values')
ax[2].set_title('Comparison of Train, Test, and Cross-Validation Metrics for MAE')
ax[2].set_xticks([2])
ax[2].set_xticklabels(['MAE'])
ax[2].legend()

plt.show()
# Out:
# Linear Regression Results:
# Train R2: 0.9234282242713254
# Train RMSE: 112.70626469018787
# Train MSE: 12702.702100414688
# Train MAE: 78.26135872548977
# Test R2: 0.9241659672602782
# Test RMSE: 113.40147120918654
# Test MSE: 12859.893672407963
# Test MAE: 78.2635837651546
# Cross-Validation Results (Average):
# CV R2: 0.912336585180352
# CV RMSE: 117.05691407946588
# CV MSE: 14649.448790617695
# CV MAE: 84.02496430064903

# %% [markdown]
# ### Summary and conclusions:
#
# The R2 SCORE scores both in training and in the test are around 0.90, which means that the chance of overfit is very low and the results look very good in this respect also in the other parameters
# RMSE, MSE, and MAE. Regarding the performance of the model itself, although its performance in general is good, there were models that worked better on the existing data and we can assume that this is because the specific model of linear regression is more sensitive to anomalies in the data.
#
# Another thing that can be understood from running the original clean data compared to the data with the new features we added and of which we did one hot encoding is that the new features we added do improve the performance of the model similar to the other models we ran,but not significantly as in other models such as decision tree and neural networks.
